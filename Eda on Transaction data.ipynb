# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
cust_data = pd.read_csv(r"C:\Users\uktiw\Downloads\New folder\New folder\Customers_Data.csv")
acc_data = pd.read_csv(r"C:\Users\uktiw\Downloads\New folder\New folder\Accounts_Data.csv")
trans_data = pd.read_csv(r"C:\Users\uktiw\Downloads\New folder\New folder\Transactions_Data.csv")

# %%
cust_data.head()
# Out:
#    customer_id           name  gender         dob   join_date region  \
# 0         1001   Gaurav Ghosh    Male  1964-02-16  2016-05-10   East
# 1         1002     Kiran Khan    Male  1967-12-10  2021-10-31   West
# 2         1003    Sara Sharma  Female  1977-08-09  2020-11-17   East
# 3         1004  Zoya Kulkarni  Female  1960-07-18  2019-02-25   East
# 4         1005   Sonia Pillai  Female  2000-03-16  2019-02-08  South
#
#       occupation
# 0        Retired
# 1  Self-Employed
# 2        Retired
# 3        Student
# 4  Self-Employed

# %%
acc_data.head()
# Out:
#    account_id  customer_id account_type   open_date   status close_date  \
# 0        2001         1646      Savings  2024-02-17   Active        NaN
# 1        2002         1717      Current  2020-09-26   Active        NaN
# 2        2003         1268      Current  2019-12-18   Active        NaN
# 3        2004         1358      Savings  2023-10-05   Active        NaN
# 4        2005         1946       Salary  2016-10-31  Dormant        NaN
#
#   branch_code
# 0       BR002
# 1       BR005
# 2       BR003
# 3       BR003
# 4       BR002

# %%
trans_data.head()
# Out:
#    txn_id  account_id    txn_date   amount txn_type channel
# 0  500001        2371  2021-07-31  2881.78    Debit  Branch
# 1  500002        2829  2022-10-28  1625.53    Debit     ATM
# 2  500003        2624  2023-02-01  4998.80    Debit     POS
# 3  500004        2690  2025-06-11  2120.18   Credit     POS
# 4  500005        2552  2024-09-15   368.87    Debit     ATM

# %%
cust_data.shape
# Out:
# (1000, 7)

# %%
cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1000 non-null   int64
#  1   name         1000 non-null   object
#  2   gender       1000 non-null   object
#  3   dob          1000 non-null   object
#  4   join_date    1000 non-null   object
#  5   region       1000 non-null   object
#  6   occupation   1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
cust_data.isnull().sum()
# Out:
# customer_id    0
# name           0
# gender         0
# dob            0
# join_date      0
# region         0
# occupation     0
# dtype: int64

# %%
acc_data.shape
# Out:
# (1500, 7)

# %%
acc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   account_id    1500 non-null   int64
#  1   customer_id   1500 non-null   int64
#  2   account_type  1500 non-null   object
#  3   open_date     1500 non-null   object
#  4   status        1500 non-null   object
#  5   close_date    127 non-null    object
#  6   branch_code   1500 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 82.2+ KB

# %%
acc_data.isnull().sum()
# Out:
# account_id         0
# customer_id        0
# account_type       0
# open_date          0
# status             0
# close_date      1373
# branch_code        0
# dtype: int64

# %%
trans_data.shape
# Out:
# (20000, 6)

# %%
trans_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   txn_id      20000 non-null  int64
#  1   account_id  20000 non-null  int64
#  2   txn_date    20000 non-null  object
#  3   amount      20000 non-null  float64
#  4   txn_type    20000 non-null  object
#  5   channel     20000 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 937.6+ KB

# %%
trans_data.isnull().sum()
# Out:
# txn_id        0
# account_id    0
# txn_date      0
# amount        0
# txn_type      0
# channel       0
# dtype: int64

# %%
cust_data['join_date']= pd.to_datetime(cust_data['join_date'])

# %%
cust_data['dob']= pd.to_datetime(cust_data['dob'])

# %%
cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1000 non-null   int64
#  1   name         1000 non-null   object
#  2   gender       1000 non-null   object
#  3   dob          1000 non-null   datetime64[ns]
#  4   join_date    1000 non-null   datetime64[ns]
#  5   region       1000 non-null   object
#  6   occupation   1000 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 54.8+ KB

# %%
acc_data['open_date']= pd.to_datetime(acc_data['open_date'])
acc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   account_id    1500 non-null   int64
#  1   customer_id   1500 non-null   int64
#  2   account_type  1500 non-null   object
#  3   open_date     1500 non-null   datetime64[ns]
#  4   status        1500 non-null   object
#  5   close_date    127 non-null    object
#  6   branch_code   1500 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 82.2+ KB

# %%
trans_data['txn_date']= pd.to_datetime(trans_data['txn_date'])
trans_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   txn_id      20000 non-null  int64
#  1   account_id  20000 non-null  int64
#  2   txn_date    20000 non-null  datetime64[ns]
#  3   amount      20000 non-null  float64
#  4   txn_type    20000 non-null  object
#  5   channel     20000 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 937.6+ KB

# %%
cust_data['dob']= pd.to_datetime(cust_data['dob'])
cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1000 non-null   int64
#  1   name         1000 non-null   object
#  2   gender       1000 non-null   object
#  3   dob          1000 non-null   datetime64[ns]
#  4   join_date    1000 non-null   datetime64[ns]
#  5   region       1000 non-null   object
#  6   occupation   1000 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 54.8+ KB

# %%
temp_df= pd.merge(trans_data, acc_data, on = 'account_id',how = 'left')

# %%
temp_df.head()
# Out:
#    txn_id  account_id   txn_date   amount txn_type channel  customer_id  \
# 0  500001        2371 2021-07-31  2881.78    Debit  Branch         1970
# 1  500002        2829 2022-10-28  1625.53    Debit     ATM         1628
# 2  500003        2624 2023-02-01  4998.80    Debit     POS         1799
# 3  500004        2690 2025-06-11  2120.18   Credit     POS         1731
# 4  500005        2552 2024-09-15   368.87    Debit     ATM         1043
#
#   account_type  open_date  status close_date branch_code
# 0       Salary 2021-07-22  Active        NaN       BR002
# 1      Savings 2022-04-16  Active        NaN       BR001
# 2      Current 2019-03-18  Active        NaN       BR001
# 3       Salary 2024-08-15  Active        NaN       BR004
# 4       Salary 2023-04-24  Active        NaN       BR002

# %%
df =pd.merge(temp_df,cust_data, on = 'customer_id', how= 'left')
df.head()
# Out:
#    txn_id  account_id   txn_date   amount txn_type channel  customer_id  \
# 0  500001        2371 2021-07-31  2881.78    Debit  Branch         1970
# 1  500002        2829 2022-10-28  1625.53    Debit     ATM         1628
# 2  500003        2624 2023-02-01  4998.80    Debit     POS         1799
# 3  500004        2690 2025-06-11  2120.18   Credit     POS         1731
# 4  500005        2552 2024-09-15   368.87    Debit     ATM         1043
#
#   account_type  open_date  status close_date branch_code         name  gender  \
# 0       Salary 2021-07-22  Active        NaN       BR002     Ria Khan    Male
# 1      Savings 2022-04-16  Active        NaN       BR001  Arjun Patel    Male
# 2      Current 2019-03-18  Active        NaN       BR001    Aarav Das  Female
# 3       Salary 2024-08-15  Active        NaN       BR004    Sonia Ali  Female
# 4       Salary 2023-04-24  Active        NaN       BR002  Rahul Menon    Male
#
#          dob  join_date region     occupation
# 0 1998-05-14 2015-12-07   East  Self-Employed
# 1 1976-12-31 2018-08-01   East       Salaried
# 2 1981-04-18 2018-03-02  South        Student
# 3 1965-01-16 2021-06-21   East        Student
# 4 1984-04-04 2021-03-31  South        Student

# %%
df = df.drop('close_date' , axis = 1)

# %%
df.head(5)
# Out:
#    txn_id  account_id   txn_date   amount txn_type channel  customer_id  \
# 0  500001        2371 2021-07-31  2881.78    Debit  Branch         1970
# 1  500002        2829 2022-10-28  1625.53    Debit     ATM         1628
# 2  500003        2624 2023-02-01  4998.80    Debit     POS         1799
# 3  500004        2690 2025-06-11  2120.18   Credit     POS         1731
# 4  500005        2552 2024-09-15   368.87    Debit     ATM         1043
#
#   account_type  open_date  status branch_code         name  gender        dob  \
# 0       Salary 2021-07-22  Active       BR002     Ria Khan    Male 1998-05-14
# 1      Savings 2022-04-16  Active       BR001  Arjun Patel    Male 1976-12-31
# 2      Current 2019-03-18  Active       BR001    Aarav Das  Female 1981-04-18
# 3       Salary 2024-08-15  Active       BR004    Sonia Ali  Female 1965-01-16
# 4       Salary 2023-04-24  Active       BR002  Rahul Menon    Male 1984-04-04
#
#    join_date region     occupation
# 0 2015-12-07   East  Self-Employed
# 1 2018-08-01   East       Salaried
# 2 2018-03-02  South        Student
# 3 2021-06-21   East        Student
# 4 2021-03-31  South        Student

# %%
sns.histplot(x = 'amount' , data = df, bins= 15 , kde=True)
# Out:
# <Axes: xlabel='amount', ylabel='Count'>

# %%
sns.countplot(x ='txn_type' ,data= df)
# Out:
# <Axes: xlabel='txn_type', ylabel='count'>

# %%
sns.countplot(x ='gender' ,data= df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(x ='region' ,data= df)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.countplot(x ='account_type' ,data= df)
# Out:
# <Axes: xlabel='account_type', ylabel='count'>

# %%
sns.lineplot(x ='branch_code', y='amount' ,data= df)
# Out:
# <Axes: xlabel='branch_code', ylabel='amount'>

# %%
sns.boxplot(x ='account_type', y='amount' ,data= df, color='red')
# Out:
# <Axes: xlabel='account_type', ylabel='amount'>

# %% [markdown]
# Top Customers by spending

# %%
df.head()
# Out:
#    txn_id  account_id   txn_date   amount txn_type channel  customer_id  \
# 0  500001        2371 2021-07-31  2881.78    Debit  Branch         1970
# 1  500002        2829 2022-10-28  1625.53    Debit     ATM         1628
# 2  500003        2624 2023-02-01  4998.80    Debit     POS         1799
# 3  500004        2690 2025-06-11  2120.18   Credit     POS         1731
# 4  500005        2552 2024-09-15   368.87    Debit     ATM         1043
#
#   account_type  open_date  status branch_code         name  gender        dob  \
# 0       Salary 2021-07-22  Active       BR002     Ria Khan    Male 1998-05-14
# 1      Savings 2022-04-16  Active       BR001  Arjun Patel    Male 1976-12-31
# 2      Current 2019-03-18  Active       BR001    Aarav Das  Female 1981-04-18
# 3       Salary 2024-08-15  Active       BR004    Sonia Ali  Female 1965-01-16
# 4       Salary 2023-04-24  Active       BR002  Rahul Menon    Male 1984-04-04
#
#    join_date region     occupation
# 0 2015-12-07   East  Self-Employed
# 1 2018-08-01   East       Salaried
# 2 2018-03-02  South        Student
# 3 2021-06-21   East        Student
# 4 2021-03-31  South        Student

# %%
df.head()
# Out:
#    txn_id  account_id   txn_date   amount txn_type channel  customer_id  \
# 0  500001        2371 2021-07-31  2881.78    Debit  Branch         1970
# 1  500002        2829 2022-10-28  1625.53    Debit     ATM         1628
# 2  500003        2624 2023-02-01  4998.80    Debit     POS         1799
# 3  500004        2690 2025-06-11  2120.18   Credit     POS         1731
# 4  500005        2552 2024-09-15   368.87    Debit     ATM         1043
#
#   account_type  open_date  status branch_code         name  gender        dob  \
# 0       Salary 2021-07-22  Active       BR002     Ria Khan    Male 1998-05-14
# 1      Savings 2022-04-16  Active       BR001  Arjun Patel    Male 1976-12-31
# 2      Current 2019-03-18  Active       BR001    Aarav Das  Female 1981-04-18
# 3       Salary 2024-08-15  Active       BR004    Sonia Ali  Female 1965-01-16
# 4       Salary 2023-04-24  Active       BR002  Rahul Menon    Male 1984-04-04
#
#    join_date region     occupation
# 0 2015-12-07   East  Self-Employed
# 1 2018-08-01   East       Salaried
# 2 2018-03-02  South        Student
# 3 2021-06-21   East        Student
# 4 2021-03-31  South        Student

# %%
df.groupby(['customer_id','name'])['amount'].sum().reset_index().sort_values(by = 'amount', ascending =False).head(10)
# Out:
#      customer_id          name     amount
# 437         1551   Isha Sharma  210254.00
# 506         1648   Meera Verma  186372.19
# 371         1472  Gaurav Singh  175972.60
# 583         1747   Isha Pillai  173365.79
# 532         1681   Sonia Ghosh  166708.75
# 16          1021    Neha Mehta  154061.17
# 97          1125   Isha Pillai  150119.36
# 182         1236  Meera Sharma  149428.69
# 212         1275  Arjun Sharma  144840.40
# 343         1440     Dev Ghosh  143982.73

# %%
df = df.rename(columns={'amount_x': 'amount'})

# %%
df.head()
# Out:
#    txn_id  account_id   txn_date   amount txn_type channel  customer_id  \
# 0  500001        2371 2021-07-31  2881.78    Debit  Branch         1970
# 1  500002        2829 2022-10-28  1625.53    Debit     ATM         1628
# 2  500003        2624 2023-02-01  4998.80    Debit     POS         1799
# 3  500004        2690 2025-06-11  2120.18   Credit     POS         1731
# 4  500005        2552 2024-09-15   368.87    Debit     ATM         1043
#
#   account_type  open_date  status branch_code         name  gender        dob  \
# 0       Salary 2021-07-22  Active       BR002     Ria Khan    Male 1998-05-14
# 1      Savings 2022-04-16  Active       BR001  Arjun Patel    Male 1976-12-31
# 2      Current 2019-03-18  Active       BR001    Aarav Das  Female 1981-04-18
# 3       Salary 2024-08-15  Active       BR004    Sonia Ali  Female 1965-01-16
# 4       Salary 2023-04-24  Active       BR002  Rahul Menon    Male 1984-04-04
#
#    join_date region     occupation
# 0 2015-12-07   East  Self-Employed
# 1 2018-08-01   East       Salaried
# 2 2018-03-02  South        Student
# 3 2021-06-21   East        Student
# 4 2021-03-31  South        Student

# %% [markdown]
# Avg transaction per customer

# %%
df.groupby(["customer_id","name"])["amount"].mean().reset_index()
# Out:
#      customer_id           name       amount
# 0           1001   Gaurav Ghosh  1811.019545
# 1           1002     Kiran Khan  2522.242667
# 2           1003    Sara Sharma  1443.765385
# 3           1004  Zoya Kulkarni  3186.384000
# 4           1006      Neha Bhat  1821.728214
# ..           ...            ...          ...
# 769         1996     Rahul Iyer  2699.491765
# 770         1997    Aarav Menon  1906.385172
# 771         1998       Dev Khan  1631.693077
# 772         1999     Sonia Nair  2094.284000
# 773         2000   Priya Kapoor  1962.517568
#
# [774 rows x 3 columns]

# %% [markdown]
# Account type with highest transaction amount

# %%
max_account= df.groupby('account_type')['amount'].sum().reset_index() .sort_values(by='amount', ascending=False).head(1)
max_account
# Out:
#   account_type       amount
# 0      Current  13876184.65

# %% [markdown]
# 1-Number of transaction done by Each customers., 2- filter out customers done less the 2 tracsactions

# %%
df.head()
# Out:
#    txn_id  account_id   txn_date   amount txn_type channel  customer_id  \
# 0  500001        2371 2021-07-31  2881.78    Debit  Branch         1970
# 1  500002        2829 2022-10-28  1625.53    Debit     ATM         1628
# 2  500003        2624 2023-02-01  4998.80    Debit     POS         1799
# 3  500004        2690 2025-06-11  2120.18   Credit     POS         1731
# 4  500005        2552 2024-09-15   368.87    Debit     ATM         1043
#
#   account_type  open_date  status branch_code         name  gender        dob  \
# 0       Salary 2021-07-22  Active       BR002     Ria Khan    Male 1998-05-14
# 1      Savings 2022-04-16  Active       BR001  Arjun Patel    Male 1976-12-31
# 2      Current 2019-03-18  Active       BR001    Aarav Das  Female 1981-04-18
# 3       Salary 2024-08-15  Active       BR004    Sonia Ali  Female 1965-01-16
# 4       Salary 2023-04-24  Active       BR002  Rahul Menon    Male 1984-04-04
#
#    join_date region     occupation
# 0 2015-12-07   East  Self-Employed
# 1 2018-08-01   East       Salaried
# 2 2018-03-02  South        Student
# 3 2021-06-21   East        Student
# 4 2021-03-31  South        Student

# %%
txn_count= df.groupby('customer_id')['txn_id'].count().reset_index().rename(columns={'txn_id':'txn_count'})

# %%
txn_count
# Out:
#      customer_id  txn_count
# 0           1001         22
# 1           1002         15
# 2           1003         13
# 3           1004         15
# 4           1006         28
# ..           ...        ...
# 769         1996         34
# 770         1997         58
# 771         1998         78
# 772         1999         10
# 773         2000         37
#
# [774 rows x 2 columns]

# %%
df= pd.merge(df,txn_count, on = 'customer_id', how = 'left')
df.head()
# Out:
#    txn_id  account_id   txn_date   amount txn_type channel  customer_id  \
# 0  500001        2371 2021-07-31  2881.78    Debit  Branch         1970
# 1  500002        2829 2022-10-28  1625.53    Debit     ATM         1628
# 2  500003        2624 2023-02-01  4998.80    Debit     POS         1799
# 3  500004        2690 2025-06-11  2120.18   Credit     POS         1731
# 4  500005        2552 2024-09-15   368.87    Debit     ATM         1043
#
#   account_type  open_date  status branch_code         name  gender        dob  \
# 0       Salary 2021-07-22  Active       BR002     Ria Khan    Male 1998-05-14
# 1      Savings 2022-04-16  Active       BR001  Arjun Patel    Male 1976-12-31
# 2      Current 2019-03-18  Active       BR001    Aarav Das  Female 1981-04-18
# 3       Salary 2024-08-15  Active       BR004    Sonia Ali  Female 1965-01-16
# 4       Salary 2023-04-24  Active       BR002  Rahul Menon    Male 1984-04-04
#
#    join_date region     occupation  txn_count
# 0 2015-12-07   East  Self-Employed         21
# 1 2018-08-01   East       Salaried         43
# 2 2018-03-02  South        Student         64
# 3 2021-06-21   East        Student         42
# 4 2021-03-31  South        Student         13

# %%
df[df['txn_count']<=2]
# Out:
#        txn_id  account_id   txn_date   amount txn_type channel  customer_id  \
# 3597   503598        3279 2021-12-09   306.29   Credit  Online         1980
# 9653   509654        3093 2023-05-12   158.83   Credit     POS         1706
# 9990   509991        3279 2022-09-06  2041.06    Debit  Branch         1980
# 17292  517293        3093 2024-02-25  2751.71   Credit  Online         1706
#
#       account_type  open_date  status branch_code           name  gender  \
# 3597       Current 2021-06-16  Active       BR001  Ishaan Khanna  Female
# 9653        Salary 2021-06-03  Active       BR001     Priya Iyer  Female
# 9990       Current 2021-06-16  Active       BR001  Ishaan Khanna  Female
# 17292       Salary 2021-06-03  Active       BR001     Priya Iyer  Female
#
#              dob  join_date region     occupation  txn_count
# 3597  1964-07-12 2020-03-02  South        Retired          2
# 9653  1961-09-20 2020-02-29  North  Self-Employed          2
# 9990  1964-07-12 2020-03-02  South        Retired          2
# 17292 1961-09-20 2020-02-29  North  Self-Employed          2
