# %% [markdown]
# Tuples: declaration, immutability
#
# Create a tuple of 5 colors.

# %%
a =('Red','black','pink','brown')
a
# Out:
# ('Red', 'black', 'pink', 'brown')

# %% [markdown]
# Print first and last element.

# %%
a[0]
# Out:
# 'Red'

# %%
a[-1]
# Out:
# 'brown'

# %% [markdown]
# Count how many times 2 appears in (1,2,2,3,4).

# %%
b= (1,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,2,9,8,7,6,5,4,3,2,2,22)

# %%
b.count(2)
# Out:
# 23

# %% [markdown]
# Try changing an element in tuple. What happens?

# %% [markdown]
# it will not happen

# %% [markdown]
# Why should student roll numbers be stored in tuple instead of list?

# %% [markdown]
# because you dont really want to change roll no it should be immutable`

# %% [markdown]
# Tuple unpacking and zip() basics

# %%
a,b,c,d,e,f,g =("Hello","Welcome","to","the","world", "of","Python" )
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(g)
# Out:
# Hello
# Welcome
# to
# the
# world
# of
# Python

# %%
name = ["Aman","Naman","Raman"]
marks = [80,90,60]
list(zip(name,marks))
# Out:
# [('Aman', 80), ('Naman', 90), ('Raman', 60)]

# %%
a= ["A","B","C","D"]
a
# Out:
# ['A', 'B', 'C', 'D']

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a= {1,2,3}
set(a)
# Out:
# {1, 2, 3}

# %%
type(a)
# Out:
# set

# %% [markdown]
# ADD

# %%
a.add("Apple")

# %%
a
# Out:
# {1, 2, 3}

# %% [markdown]
# Subs

# %%
a.remove("Apple")

# %%
a
# Out:
# {1, 2, 3}

# %%
a.add("Apple")

# %%
a
# Out:
# {1, 2, 3, 'Apple'}

# %%
a.discard("Apple")

# %%
a
# Out:
# {1, 2, 3}

# %%
a = {1,2,3,4}
b = {4,5,6,7}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a.intersection(b)
# Out:
# {4}

# %%
a.difference(b)
# Out:
# {1, 2, 3}

# %%
b.difference(a)
# Out:
# {5, 6, 7}

# %%
a.symmetric_difference(b)
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
a = {1, 2, 3, 5, 6, 7}

# %%
list(a)
# Out:
# [1, 2, 3, 5, 6, 7]

# %% [markdown]
# DICTIONARY

# %%
student = {"Name":"Meena","Age":6,"City":"Mumbai"}

# %%
student
# Out:
# {'Name': 'Meena', 'Age': 6, 'City': 'Mumbai'}

# %%
student.keys()
# Out:
# dict_keys(['Name', 'Age', 'City'])

# %%
student.values()
# Out:
# dict_values(['Meena', 6, 'Mumbai'])

# %%
student.items()
# Out:
# dict_items([('Name', 'Meena'), ('Age', 6), ('City', 'Mumbai')])

# %%
for i ,j in student.items():
    print(f"{i}--->{j}")
# Out:
# Name--->Meena
# Age--->6
# City--->Mumbai

# %% [markdown]
# "Create a dictionary of 3 students with names as keys and marks as values.
#
# Print the marks of a specific student.
#
# Add a new student.
#
# Update marks of one student."

# %%
students= {"Meena":80,"Reena":90,"Teena":89,"Leena":98}

# %%
print(students["Meena"])
# Out:
# 80

# %% [markdown]
# Add a new student.`

# %%
students["Veena"]=98

# %%
students
# Out:
# {'Meena': 80, 'Reena': 90, 'Teena': 89, 'Leena': 98, 'Veena': 98}

# %% [markdown]
# Update marks of one student

# %%
students["Meena"]=90

# %%
students
# Out:
# {'Meena': 90, 'Reena': 90, 'Teena': 89, 'Leena': 98, 'Veena': 98}

# %% [markdown]
# Loop through Dictionary & Print

# %% [markdown]
# Keys Element

# %%
for i in students.keys():
    print(i)
# Out:
# Meena
# Reena
# Teena
# Leena
# Veena

# %%
for i in students.values():
    print(i)
# Out:
# 90
# 90
# 89
# 98
# 98

# %%
for i in students.items():
    print(i)
# Out:
# ('Meena', 90)
# ('Reena', 90)
# ('Teena', 89)
# ('Leena', 98)
# ('Veena', 98)

# %%
def getWater(name):
    print("Welcome",name)
    print("Turn Left")
    print("Turn Right")
    print("Turn Left")
    print("Turn Right")
    print("Go Straight")
    print("Pick Glass")
    print("fill it with water")
    print("Turn Left")
    print("Turn Right")
    print("Turn Left")
    print("Turn Right")

# %%
getWater("Aman Kumar")
# Out:
# Welcome Aman Kumar
# Turn Left
# Turn Right
# Turn Left
# Turn Right
# Go Straight
# Pick Glass
# fill it with water
# Turn Left
# Turn Right
# Turn Left
# Turn Right

# %%
def EvenOdd(a):
    if(a%2==0):
        print("The No is Even")
    else:
        print("The No is Odd")

# %%
EvenOdd(12345678987654321)
# Out:
# The No is Odd

# %%
def add(a,b):
    print("Addition of number",a+b)

# %%
def subs(a,b):
    print("Addition of number",a-b)

# %%
def multiply(a,b):
    print("Multiplication of number",a*b)

# %%
def Div(a,b):
    print("Divition of number",a/b)

# %%
add(9,8)
subs(9,8)
multiply(9,8)
Div(9,8)
# Out:
# Addition of number 17
# Addition of number 1
# Multiplication of number 72
# Divition of number 1.125
