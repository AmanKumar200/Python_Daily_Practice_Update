# %% [markdown]
# Load the dataset into a DataFrame df_ipl and display first 5 rows.

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\uktiw\Downloads\Python\IPL2025Batters.csv")

# %% [markdown]
# Display shape and column names of the dataset.

# %%
df.shape
# Out:
# (156, 14)

# %%
df.head()
# Out:
#          Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2        Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3       Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4     Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38
# 2     0    8  66  19
# 3     0    6  62  24
# 4     1    6  56  37

# %%
print(df.columns)
# Out:
# Index(['Player Name', 'Team', 'Runs', 'Matches', 'Inn', 'No', 'HS', 'AVG',
#        'BF', 'SR', '100s', '50s', '4s', '6s'],
#       dtype='object')

# %% [markdown]
# Display only "Player Name" and "Runs" columns.

# %%
print(df[['Player Name','Runs']])
# Out:
#            Player Name  Runs
# 0        Sai Sudharsan   759
# 1    Surya Kumar Yadav   717
# 2          Virat Kohli   657
# 3         Shubman Gill   650
# 4       Mitchell Marsh   627
# ..                 ...   ...
# 151      Khaleel Ahmed     1
# 152       Mohit Sharma     1
# 153   Donovan Ferreira     1
# 154      Digvesh Singh     1
# 155     Manoj Bhandage     1
#
# [156 rows x 2 columns]

# %% [markdown]
# Display data types using info().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB

# %% [markdown]
# Select players who scored more than 500 runs.

# %%
df[df['Runs']>500]
# Out:
#           Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0       Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 1   Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 2         Virat Kohli   RCB   657       15   15   3   73*  54.75  454  144.71
# 3        Shubman Gill    GT   650       15   15   2   93*  50.00  417  155.87
# 4      Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 5        Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345  175.07
# 6    Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 7   Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342  160.52
# 8           K L Rahul    DC   539       13   13   3  112*  53.90  360  149.72
# 9         Jos Buttler    GT   538       14   13   4   97*  59.78  330  163.03
# 10    Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267  196.25
#
#     100s  50s  4s  6s
# ...

# %%
df[df['Runs']>500,["Player Name"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Runs, Length: 156, dtype: bool, ['Player Name'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df[df['Runs']>500,["Player Name"]]
#
# ...

# %% [markdown]
# Select "Player Name" and "SR" where SR > 150 using loc.

# %%
df.loc[df["SR"]>150, ["Player Name", "SR"]]
# Out:
#              Player Name      SR
# 0          Sai Sudharsan  156.17
# 1      Surya Kumar Yadav  167.91
# 3           Shubman Gill  155.87
# 4         Mitchell Marsh  163.70
# 5           Shreyas Iyer  175.07
# 6       Yashasvi Jaiswal  159.71
# 7      Prabhsimran Singh  160.52
# 9            Jos Buttler  163.03
# 10       Nicholas Pooran  196.25
# 11      Heinrich Klaasen  172.69
# 12         Priyansh Arya  179.24
# 14       Abhishek Sharma  193.39
# 16             Phil Salt  175.98
# 17           Riyan Parag  166.52
# 19        Ryan Rickelton  150.97
# 20           Travis Head  162.60
# 23          Ishan Kishan  152.58
# 24        Shashank Singh  153.50
# 26           Dhruv Jurel  156.33
# 31        Tristan Stubbs  150.75
# 33   Sherfane Rutherford  157.29
# 35           Josh Inglis  162.57
# 37            Axar Patel  157.48
# 38         Jitesh Sharma  176.35
# 39   Vaibhav Suryavanshi  206.55
# 40            Naman Dhir  182.60
# 41      Devdutt Padikkal  150.60
# ...

# %% [markdown]
# Select players from team "RCB".

# %%
df.loc[df['Team'] == "RCB"], ["Player Name","Team"]
# Out:
# (           Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF      SR  \
#  2          Virat Kohli  RCB   657       15   15   3  73*  54.75  454  144.71
#  16           Phil Salt  RCB   403       13   13   1   65  33.58  229  175.98
#  28       Rajat Patidar  RCB   312       15   14   1   64  24.00  217  143.77
#  38       Jitesh Sharma  RCB   261       15   11   4  85*  37.29  148  176.35
#  41    Devdutt Padikkal  RCB   247       10   10   1   61  27.44  164  150.60
#  56           Tim David  RCB   187       12    9   6  50*  62.33  101  185.14
#  72    Liam Livingstone  RCB   112       10    8   1   54  16.00   84  133.33
#  73       Krunal Pandya  RCB   109       15    7   1  73*  18.17   86  126.74
#  77      Mayank Agarwal  RCB    95        4    4   1  41*  31.67   64  148.43
#  84    Romario Shepherd  RCB    70        8    3   1  53*  35.00   24  291.66
#  86       Jacob Bethell  RCB    67        2    2   0   55  33.50   39  171.79
# ...

# %% [markdown]
# Select players where Runs > 600 and display only "Player Name" and "Team".

# %%
df.loc[df['Runs']>600, ["Player Name","Team"]]
# Out:
#          Player Name  Team
# 0      Sai Sudharsan    GT
# 1  Surya Kumar Yadav    MI
# 2        Virat Kohli   RCB
# 3       Shubman Gill    GT
# 4     Mitchell Marsh   LSG
# 5       Shreyas Iyer  PBKS

# %% [markdown]
# Select players where 50s >= 5.

# %%
df[df['50s']>=5]
# Out:
#           Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0       Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 1   Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 2         Virat Kohli   RCB   657       15   15   3   73*  54.75  454  144.71
# 3        Shubman Gill    GT   650       15   15   2   93*  50.00  417  155.87
# 4      Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 5        Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345  175.07
# 6    Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 9         Jos Buttler    GT   538       14   13   4   97*  59.78  330  163.03
# 10    Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267  196.25
# 13      Aiden Markram   LSG   445       13   13   0    66  34.23  299  148.82
#
#     100s  50s  4s  6s
# 0      1    6  88  21
# 1      0    5  69  38
# 2      0    8  66  19
# ...

# %% [markdown]
# Select players with at least one century (100s > 0).

# %%
df[df['100s']>0]
# Out:
#             Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 0         Sai Sudharsan    GT   759       15   15   1  108*  54.21  486
# 4        Mitchell Marsh   LSG   627       13   13   0   117  48.23  383
# 8             K L Rahul    DC   539       13   13   3  112*  53.90  360
# 11     Heinrich Klaasen   SRH   487       13   13   2  105*  44.27  282
# 12        Priyansh Arya  PBKS   475       17   17   0   103  27.94  265
# 14      Abhishek Sharma   SRH   439       14   13   0   141  33.77  227
# 23         Ishan Kishan   SRH   354       14   13   3  106*  35.40  232
# 36         Rishabh Pant   LSG   269       14   13   2  118*  24.45  202
# 39  Vaibhav Suryavanshi    RR   252        7    7   0   101  36.00  122
#
#         SR  100s  50s  4s  6s
# 0   156.17     1    6  88  21
# 4   163.70     1    6  56  37
# 8   149.72     1    3  52  21
# 11  172.69     1    1  42  25
# 12  179.24     1    2  55  25
# 14  193.39     1    2  46  28
# ...

# %% [markdown]
# Select players where Runs > 500 AND SR > 140.

# %%
df[(df['Runs']>500) & (df['SR']>140)]
# Out:
#           Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0       Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 1   Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 2         Virat Kohli   RCB   657       15   15   3   73*  54.75  454  144.71
# 3        Shubman Gill    GT   650       15   15   2   93*  50.00  417  155.87
# 4      Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 5        Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345  175.07
# 6    Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 7   Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342  160.52
# 8           K L Rahul    DC   539       13   13   3  112*  53.90  360  149.72
# 9         Jos Buttler    GT   538       14   13   4   97*  59.78  330  163.03
# 10    Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267  196.25
#
#     100s  50s  4s  6s
# ...

# %% [markdown]
# Select players where Team = "MI" AND Runs > 400.

# %%
df[(df["Team"]=='MI') & (df["Runs"]>400)]
# Out:
#           Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF      SR  \
# 1   Surya Kumar Yadav   MI   717       16   16   5  73*  65.18  427  167.91
# 15       Rohit Sharma   MI   418       15   15   1   81  29.86  280  149.28
#
#     100s  50s  4s  6s
# 1      0    5  69  38
# 15     0    4  41  22

# %% [markdown]
# Sort players by Runs in descending order.

# %% [markdown]
# Difference between df["Runs"] and df[["Runs"]]

# %%
df["Runs"]
# Out:
# 0      759
# 1      717
# 2      657
# 3      650
# 4      627
#       ...
# 151      1
# 152      1
# 153      1
# 154      1
# 155      1
# Name: Runs, Length: 156, dtype: int64

# %%
df[["Runs"]]
# Out:
#      Runs
# 0     759
# 1     717
# 2     657
# 3     650
# 4     627
# ..    ...
# 151     1
# 152     1
# 153     1
# 154     1
# 155     1
#
# [156 rows x 1 columns]
