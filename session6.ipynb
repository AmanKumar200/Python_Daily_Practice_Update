# %%
with open(r"C:\Users\uktiw\Downloads\Python\abc.text","w") as f:
    f.write("Oh Hello There")

# %%
with open(r"C:\Users\uktiw\Downloads\Python\abc.text","r") as f:
    print(f.read())
# Out:
# Oh Hello There
# Hello how are you guys

# %%
with open(r"C:\Users\uktiw\Downloads\Python\abc.text","a") as f:
    f.write("\nHello how are you guys")

# %%
data= ["Apple","Mango","Banana","Grapes"]
with open(r"C:\Users\uktiw\Downloads\Python\abc.text","w") as f:
    for i in data:
        f.write("\n"+i)

# %%
with open(r"C:\Users\uktiw\Downloads\Python\abc.text","r") as f:
    print(f.read())
# Out:
# Apple
# Mango
# Banana
# Grapes

# %%
import csv
with open(r"C:\Users\uktiw\Downloads\Python\Student_details.csv","w",newline="")as f:
    writer=csv.writer(f)
    writer.writerow(["Name","Age","City"])
    writer.writerow(["Aman",24,"Munger"])

# %%
import csv
with open(r"C:\Users\uktiw\Downloads\Python\Student_details.csv","r")as f:
    reader=csv.reader(f)
    for i in reader:
        print(i)
# Out:
# ['Name', 'Age', 'City']
# ['Aman', '24', 'Munger']
# ['Raman', '25', 'Ara']
# ['Baman', '26', 'Mirzapur']

# %%
import csv
with open(r"C:\Users\uktiw\Downloads\Python\Student_details.csv","a",newline="")as f:
    writer=csv.writer(f)
    writer.writerow(["Raman",25,"Ara"])
    writer.writerow(["Baman",26,"Mirzapur"])

# %%
import json
data = [
        
    { "name":"Aman",
      "age":24,
      "city":"Munger"         
}
]
with open(r"C:\Users\uktiw\Downloads\Python\employee.json","w") as f:
    json.dump(data,f,indent=4)

# %%
with open(r"C:\Users\uktiw\Downloads\Python\employee.json","r") as f:
    print(json.load(f))
# Out:
# [{'name': 'Aman', 'age': 24, 'city': 'Munger'}, {'name': 'Raman', 'age': 25, 'city': 'Delhi'}]

# %%
data = [
        
    { "name":"Aman",
      "age":24,
      "city":"Munger"         
}
]
data1={"name":"Raman",
      "age":25,
      "city":"Delhi"
}
data.append(data1)
with open(r"C:\Users\uktiw\Downloads\Python\employee.json","w") as f:
    json.dump(data,f,indent=4)
